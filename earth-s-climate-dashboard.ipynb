# %% [markdown]
# <a href="https://www.kaggle.com/code/jarredpriester/earth-s-climate-dashboard?scriptVersionId=109031769" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Earth's Climate Dashboard
#
# by Jarred Priester

# %% [markdown]
# # *Temperature*

# %%
#importing the libraries we will be needing
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px # data visualizations

#downloading the global temperature dataset
temp = pd.read_csv("../input/global-annual-mean-temperature/Global_annual_mean_temp.csv")

#creating a line chart
fig = px.line(temp, x='Year', y='No_Smoothing',
              color_discrete_sequence = ['orange'],
              markers=True,
              title="Global Surface Temperatures",
              labels={"No_Smoothing":"Temperature Difference in Celsius"}
              )
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# # *Ocean Temperature*

# %%
#downloading the ocean heat dataset
octemp = pd.read_csv('../input/ocean-heat-anomaly/ohc_levitus_climdash_seasonal.csv')

#creating a line chart
fig = px.line(octemp, x='Year', y='heat content anomaly (10^22  Joules)',
              color_discrete_sequence = ['red'],
              markers=True,
              title='Ocean Heat Content')
fig.show()
# Out:
# <div>                            <div id="ac17729a-ef5f-4db3-8750-954b27ffee32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac17729a-ef5f-4db3-8750-954b27ffee32")) {                    Plotly.newPlot(                        "ac17729a-ef5f-4db3-8750-954b27ffee32",                        [{"hovertemplate":"Year=%{x}<br>heat content anomaly (10^22  Joules)=%{y}<extra></extra>","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998
# ...

# %% [markdown]
# # *Carbon Dioxide*

# %%
#downloading the co2 dataset
co2 = pd.read_csv("../input/noaa-monthly-co2-ppm/co2_mm_mlo.csv")

#creating a line chart
fig = px.line(co2, x='decimal date', y='average',
              color_discrete_sequence = ['purple'],
              markers=True,
              hover_data=['year','month','average'],
              title='Mauna Loa Observatory CO2 Parts Per Million',
              labels={'decimal date':'year', 'average':'CO2 ppm'})
fig.show()
# Out:
# <div>                            <div id="86df09c0-9059-41da-a4d6-e957c96eeefd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86df09c0-9059-41da-a4d6-e957c96eeefd")) {                    Plotly.newPlot(                        "86df09c0-9059-41da-a4d6-e957c96eeefd",                        [{"customdata":[[1958,3],[1958,4],[1958,5],[1958,6],[1958,7],[1958,8],[1958,9],[1958,10],[1958,11],[1958,12],[1959,1],[1959,2],[1959,3],[1959,4],[1959,5],[1959,6],[1959,7],[1959,8],[1959,9],[1959,10],[1959,11],[1959,12],[1960,1],[1960,2],[1960,3],[1960,4],[1960,5],[1960,6],[1960,7],[1960,8],[1960,9],[1960,10],[1960,11],[1960,12],[1961,1],[1961,2],[1961,3],[1961,4],[1961,5],[1961,6],[1961,7],[1961,8],[1961,9],[1961,10],[1961,11],[1961,12],[1962,1],[1962,2],[1962,3]
# ...

# %% [markdown]
# # *Methane*

# %%
#downloading the ch4 dataset
ch4 = pd.read_csv("../input/global-monthly-methane-observations/Global_monthly_mean_ch4.csv")

#creating a line chart
fig = px.line(ch4, x='decimal', y='average',
              color_discrete_sequence = ['pink'],
              markers=True,
              title='Global Methane Parts Per Billion',
              labels={'decimal':'year','average':'CH4 ppb'})
fig.show()
# Out:
# <div>                            <div id="fde20800-8723-427c-a21b-ee242e96caf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fde20800-8723-427c-a21b-ee242e96caf0")) {                    Plotly.newPlot(                        "fde20800-8723-427c-a21b-ee242e96caf0",                        [{"hovertemplate":"year=%{x}<br>CH4 ppb=%{y}<extra></extra>","legendgroup":"","line":{"color":"pink","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[1983.542,1983.625,1983.708,1983.792,1983.875,1983.958,1984.042,1984.125,1984.208,1984.292,1984.375,1984.458,1984.542,1984.625,1984.708,1984.792,1984.875,1984.958,1985.042,1985.125,1985.208,1985.292,1985.375,1985.458,1985.542,1985.625,1985.708,1985
# ...

# %% [markdown]
# # *Arctic Ice*

# %%
#downloading the arctic ice dataset
ice = pd.read_csv("../input/arctic-sea-ice-extent/arctic_ice_extent.csv")

#creating a line chart
fig = px.line(ice, x='year', y='extent',
              color_discrete_sequence = ['light blue'],
              markers=True,
              title='Arctic Sea Ice',
              labels={'extent': 'million sq km'}
              )
fig.show()
# Out:
# <div>                            <div id="3be55b65-d27f-43de-b319-1f133e546d61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3be55b65-d27f-43de-b319-1f133e546d61")) {                    Plotly.newPlot(                        "3be55b65-d27f-43de-b319-1f133e546d61",                        [{"hovertemplate":"year=%{x}<br>million sq km=%{y}<extra></extra>","legendgroup":"","line":{"color":"light blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y
# ...

# %% [markdown]
# # *Antarctica Mass*

# %%
#downloading the antarctica mass dataset
antarctica = pd.read_csv("../input/antarctica-mass/Antartica_mass.csv")

#creating a line chart
fig = px.line(antarctica, x='year', y='Antarctic mass',
              color_discrete_sequence = ['black'],
              markers=True,
              title='Antarctica Mass',
              labels={'Antarctic mass':'Mass in Gt'}
             )
fig.show()
# Out:
# <div>                            <div id="4a9965d0-272f-49d5-b8a3-009fd3a6a3bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a9965d0-272f-49d5-b8a3-009fd3a6a3bc")) {                    Plotly.newPlot(                        "4a9965d0-272f-49d5-b8a3-009fd3a6a3bc",                        [{"hovertemplate":"year=%{x}<br>Mass in Gt=%{y}<extra></extra>","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2002.29,2002.35,2002.62,2002.71,2002.79,2002.87,2002.96,2003.04,2003.12,2003.2,2003.29,2003.36,2003.54,2003.62,2003.71,2003.79,2003.87,2003.96,2004.02,2004.13,2004.21,2004.29,2004.37,2004.46,2004.54,2004.62,2004.71,2004.79,2004.87,2004.96,2005
# ...

# %% [markdown]
# # *Sea Levels*

# %%
#downloading the sea level dataset
sealevels = pd.read_csv('../input/global-sea-level-rise/Global_sea_level_rise.csv')

#creating a line chart
fig = px.line(sealevels, x='date', y='mmfrom1993-2008average',
              color_discrete_sequence = ['blue'],
              markers=True,
              title='Global Sea Levels',
              labels={'mmfrom1993-2008average':'mm from average'}
             )
fig.show()
# Out:
# <div>                            <div id="46e5aa21-609e-4dcb-baef-4b31b494ae6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46e5aa21-609e-4dcb-baef-4b31b494ae6f")) {                    Plotly.newPlot(                        "46e5aa21-609e-4dcb-baef-4b31b494ae6f",                        [{"hovertemplate":"date=%{x}<br>mm from average=%{y}<extra></extra>","legendgroup":"","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":["07/15/1880","07/15/1881","07/15/1882","07/15/1883","07/15/1884","07/15/1885","07/15/1886","07/15/1887","07/15/1888","07/15/1889","07/15/1890","07/15/1891","07/15/1892","07/15/1893","07/15/1894","07/15/1895","07/15/1896","07/15/1897","07/1
# ...

# %% [markdown]
# # *Population*

# %%
#downloading the global population dataset
pop = pd.read_csv('../input/global-population/Global_annual_population.csv')

#creating a line chart
fig = px.line(pop, x='Year', y=' Population',
              color_discrete_sequence = ['green'],
              markers=True,
              title='Global Population Estimations by Year',
              labels={' Population':'Population in Billions'}
             )
fig.show()
# Out:
# <div>                            <div id="d6de411b-37b5-4013-9418-1aef7f4a19b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6de411b-37b5-4013-9418-1aef7f4a19b6")) {                    Plotly.newPlot(                        "d6de411b-37b5-4013-9418-1aef7f4a19b6",                        [{"hovertemplate":"Year=%{x}<br>Population in Billions=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2
# ...

# %% [markdown]
# *inspired by*
# [NASA's Dashboard](https://climate.nasa.gov/)
# [NOAA's Dashboard](https://www.climate.gov/climatedashboard)
